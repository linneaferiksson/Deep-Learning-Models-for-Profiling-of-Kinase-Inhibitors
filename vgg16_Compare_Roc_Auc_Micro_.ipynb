# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import pandas as pd
from PIL import Image
import random
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# TensorFlow and Keras
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.regularizers import l2
#from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import utils 

# import keras
from tensorflow.keras.utils import multi_gpu_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import metrics
from tensorflow.keras import optimizers 

print(tf.__version__)
# Out:
# 2.1.0

# %%
# Out:
# Enter first directory name of roc_auc for ResNet50 with Adam:  /home/jovyan/scratch-shared/Linnea/ResNet/ResNet50 - Adam/rocauc_resnet50_pretrained_adam_lr0.0001_batch32.csv

# %%
#roc_auc_resnet50_adam=pd.read_csv('/home/jovyan/scratch-shared/Linnea/ResNet/ResNet50 - Adam/rocauc_resnet50_pretrained_adam_lr0.0001_batch32.csv')

# %%
#roc_auc_resnet50_adam
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, target/activity, roc area]
# Index: []

# %%
micro_roc_auc_vgg16_adam = 0.871808541506585
micro_roc_auc_vgg16_sgd = 0.5306146991768443
micro_roc_auc_vgg16_notpretrained = 0.8104027215083275 #KÖR DEN KODEN IGEN OCH SPARA BILD OCH VÄRDEN

micro_roc_auc = [micro_roc_auc_vgg16_adam, micro_roc_auc_vgg16_sgd, micro_roc_auc_vgg16_notpretrained]
micro_roc_auc_labels = ['micro_roc_auc_vgg16_adam', 'micro_roc_auc_vgg16_sgd', 'micro_roc_auc_vgg16_notpretrained']

# %%
#micro_roc_auc_resnet50_adam.savetxt('test.txt', delimiter=',') #SAVE ROC_AUC

# %%
micro_roc_auc
micro_roc_auc_labels
# Out:
# ['micro_roc_auc_vgg16_adam',
#  'micro_roc_auc_vgg16_sgd',
#  'micro_roc_auc_vgg16_notpretrained']

# %%
micro_roc_auc_resnet50 = []
micro_roc_auc_resnet50 = pd.DataFrame({"model": micro_roc_auc_labels,
                                      "roc_auc(micro) for VGG16 models": micro_roc_auc})

micro_roc_auc_resnet50
# Out:
#                                model  roc_auc(micro) for VGG16 models
# 0           micro_roc_auc_vgg16_adam                         0.871809
# 1            micro_roc_auc_vgg16_sgd                         0.530615
# 2  micro_roc_auc_vgg16_notpretrained                         0.810403

# %%
x = micro_roc_auc_resnet50.plot.hist(figsize=(4, 2))
#plt.savefig('VGG16_UNFINISHED_hist_MiCoPh_MiSyHo_may14.png', dpi=300) # SAVE FIGURE

# %%
img_loss_adam = mpimg.imread('/home/jovyan/scratch-shared/Linnea/VGG16/pretrained, Adam, lr0.0001, batch size 32/loss_VGG16_pretrained_adam_lr0.0001_batch32.png')
img_loss_sgd = mpimg.imread('/home/jovyan/scratch-shared/Linnea/VGG16/pretrained, SGD, lr0.0001, batch size 32/loss_VGG16_pretrained_SGD_lr0.0001_batch32.png')
#img_loss_notpretrained = mpimg.imread('/home/jovyan/scratch-shared/Linnea/ResNet/ResNet50 - not pretrained/loss_resnet50_adam_lr0.0001_batch32.png')

# %%
plt.figure(num=3, figsize=(18, 12), dpi=200)


plt.subplot(3,1,1)
plt.title('VGG16: Pretrained, Optimizer=SGD')
plt.imshow(img_loss_sgd)

plt.subplot(3,1,2)
plt.title('VGG16: Pretrained, Optimizer=Adam')
plt.imshow(img_loss_adam)

# plt.subplot(3,1,3)
#plt.title('VGG16 Not pretrained: No weights and Optimizer=Adam, lr=0.0001, batch size=32')
 #plt.imshow(img_loss_notpretrained)
plt.show()

#plt.savefig('VGG16_UNFINISHED_loss_MiCoPh_MiSyHo_may14.png', dpi=300) # SAVE FIGURE
